# %%
# Install necessary packages
# !pip install langchain together sqlalchemy langchain_community langchain_experimental transformers
# Out:
# Requirement already satisfied: langchain in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (0.1.20)
# Requirement already satisfied: together in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (0.2.11)
# Requirement already satisfied: sqlalchemy in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (2.0.28)
# Requirement already satisfied: langchain_community in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (0.0.38)
# Requirement already satisfied: langchain_experimental in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (0.0.58)
# Requirement already satisfied: transformers in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (4.40.1)
# Requirement already satisfied: PyYAML>=5.3 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from langchain) (6.0.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from langchain) (3.9.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from langchain) (0.6.4)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.52 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from langchain) (0.1.52)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from langchain) (0.0.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from langchain) (0.1.38)
# Requirement already satisfied: numpy<2,>=1 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from langchain) (2.7.1)
# Requirement already satisfied: requests<3,>=2 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from langchain) (8.2.3)
# Requirement already satisfied: sseclient-py<2.0.0,>=1.7.2 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from together) (1.8.0)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from together) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from together) (4.66.4)
# Requirement already satisfied: typer<0.10.0,>=0.9.0 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from together) (0.9.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from sqlalchemy) (4.11.0)
# Requirement already satisfied: filelock in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from transformers) (0.20.3)
# Requirement already satisfied: packaging>=20.0 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from transformers) (23.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from transformers) (2023.10.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from transformers) (0.4.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.21.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.10.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from langchain-core<0.2.0,>=0.1.52->langchain) (1.33)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from pydantic<3,>=1->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from pydantic<3,>=1->langchain) (2.18.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2024.2.2)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from typer<0.10.0,>=0.9.0->together) (8.1.7)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.2.0,>=0.1.52->langchain) (2.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain) (1.0.0)

# %%
# !pip install langchain-core
# Out:
# Requirement already satisfied: langchain-core in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (0.1.52)
# Requirement already satisfied: PyYAML>=5.3 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from langchain-core) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from langchain-core) (0.1.38)
# Requirement already satisfied: packaging<24.0,>=23.2 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from langchain-core) (23.2)
# Requirement already satisfied: pydantic<3,>=1 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from langchain-core) (2.7.1)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from langchain-core) (8.2.3)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core) (2.4)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.0->langchain-core) (3.10.0)
# Requirement already satisfied: requests<3,>=2 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.0->langchain-core) (2.31.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from pydantic<3,>=1->langchain-core) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from pydantic<3,>=1->langchain-core) (2.18.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from pydantic<3,>=1->langchain-core) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.0->langchain-core) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.0->langchain-core) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.0->langchain-core) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/patrickribersorensen/anaconda3/envs/bds/lib/python3.11/site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.0->langchain-core) (2024.2.2)

# %%
import os
from langchain import SQLDatabase
from langchain_experimental.sql import SQLDatabaseSequentialChain, SQLDatabaseChain
from langchain.chains import LLMChain
from langchain.prompts import PromptTemplate
from langchain_core.runnables.base import RunnableLambda
from pydantic import BaseModel
from typing import List
from huggingface_hub import login
from langchain_community.llms import LlamaCpp
from llama_cpp import Llama

# %%
import sqlite3
import pandas as pd
import pickle

# %%
# Define the SQLite database connection string
sqlite_uri = "sqlite:////Users/patrickribersorensen/Documents/BDS/Coding/LLM_news/news_database.db"
db = SQLDatabase.from_uri(sqlite_uri)

# %%
def setup():
    # Load your trained SVM model
    with open("svm_classifier.pkl", "rb") as f:
        svm_classifier = pickle.load(f)

    # Load the TF-IDF vectorizer
    with open("tfidf_vectorizer.pkl", "rb") as f:
        vectorizer = pickle.load(f)

    # Connect to SQLite database
    conn = sqlite3.connect("news_database.db")
    cursor = conn.cursor()

    return svm_classifier, vectorizer, cursor

svm_classifier, vectorizer, cursor = setup()

# %%
# Function to fetch news articles from the database
def fetch_news():
    cursor.execute("SELECT id, title, published_at, name, content, url, url_to_image FROM news_items")
    news_data = cursor.fetchall()
    news_df = pd.DataFrame(news_data, columns=['ID', 'Title', 'Published_At', 'Name', 'Content', 'URL', 'URL_To_Image'])
    return news_df

# Load the dataset of news articles
news_df = fetch_news()

# %%
news_df
# Out:
#         ID                                              Title  \
# 0        1  Blinken presses Hamas to seal cease-fire with ...
# 1        2  Police on campus at Columbia and UCLA as prote...
# 2        3  Arizona Senate OKs bill to repeal the state's ...
# 3        4  Rwanda: Civil servants mount court challenge o...
# 4        5  United Methodists repeal longstanding ban on L...
# ...    ...                                                ...
# 1458  1459  Norway, Ireland and Spain say they will recogn...
# 1459  1460  Buy-now, pay-later returns and disputes are ab...
# 1460  1461  Lack of staffing led to 'deeply concerning' co...
# 1461  1462  After years in decline, U.S. drowning deaths a...
# 1462  1463  6 key facts about abortion laws and the 2024 e...
#
#                     Published_At              Name  \
# 0     2024-05-01 20:10:00.000000  Associated Press
# 1     2024-05-01 20:04:00.000000               CNN
# 2     2024-05-01 20:04:00.000000  Associated Press
# 3     2024-05-01 19:40:45.000000          BBC News
# 4     2024-05-01 19:02:00.000000  Associated Press
# ...                          ...               ...
# 1458  2024-05-22 08:03:12.000000               NPR
# 1459  2024-05-22 11:00:29.000000               NPR
# 1460  2024-05-22 16:25:20.000000               NPR
# 1461  2024-05-22 21:43:09.000000               NPR
# 1462  2024-05-22 09:00:57.000000               NPR
#
#                                                 Content  \
# 0     JERUSALEM (AP) U.S. Secretary of State Antony ...
# 1     In a photo shared with CNN by Tyler Katzenberg...
# 2     PHOENIX (AP) The Arizona Legislature approved ...
# 3
# 4     CHARLOTTE, N.C. (AP) United Methodist delegate...
# ...                                                 ...
# 1458  Norway's Prime Minister Jonas Gahr Store speak...
# 1459  The Consumer Financial Protection Bureau is re...
# 1460  The main entrance to FCI Sheridan in Oregon.\r...
# 1461  A child watches others swim at the Emancipatio...
# 1462  Loading...\r\nIn the nearly two years since th...
#
#                                                     URL  \
# 0     https://apnews.com/article/israel-hamas-war-ne...
# 1     https://www.cnn.com/business/live-news/univers...
# 2     https://apnews.com/article/arizona-abortion-18...
# 3         https://www.bbc.com/news/uk-politics-68934480
# 4     https://apnews.com/article/united-methodist-lg...
# ...                                                 ...
# 1458  https://www.npr.org/2024/05/22/1252853968/norw...
# 1459  https://www.npr.org/2024/05/22/1252736063/buy-...
# 1460  https://www.npr.org/2024/05/22/1252764293/sher...
# 1461  https://www.npr.org/2024/05/22/1252976430/drow...
# 1462  https://www.npr.org/sections/health-shots/2024...
#
#                                            URL_To_Image
# 0     https://dims.apnews.com/dims4/default/18e850d/...
# 1     https://cdn.cnn.com/cnnnext/dam/assets/2404302...
# 2     https://dims.apnews.com/dims4/default/e2ac86c/...
# 3     https://ichef.bbci.co.uk/news/1024/branded_new...
# 4     https://dims.apnews.com/dims4/default/e4e9679/...
# ...                                                 ...
# 1458  https://media.npr.org/assets/img/2024/05/22/ap...
# 1459  https://media.npr.org/assets/img/2024/05/21/ge...
# 1460  https://media.npr.org/assets/img/2024/05/21/fc...
# 1461  https://media.npr.org/assets/img/2024/05/22/ge...
# 1462  https://media.npr.org/include/images/facebook-...
#
# [1463 rows x 7 columns]

# %%
# import pandas as pd
# import sqlite3
# import pickle

# # Define the setup function
# def setup():
#     # Load your trained SVM model
#     with open("svm_classifier.pkl", "rb") as f:
#         svm_classifier = pickle.load(f)

#     # Load the TF-IDF vectorizer
#     with open("tfidf_vectorizer.pkl", "rb") as f:
#         vectorizer = pickle.load(f)

#     # Connect to SQLite database
#     conn = sqlite3.connect("news_database.db")
#     cursor = conn.cursor()

#     return svm_classifier, vectorizer, cursor

# # Call the setup function to get SVM classifier, TF-IDF vectorizer, and cursor
# svm_classifier, vectorizer, cursor = setup()

# # Function to predict sentiment for a given title
# def predict_sentiment(title):
#     # Vectorize the title
#     title_vectorized = vectorizer.transform([title])

#     # Make prediction using SVM classifier
#     prediction = svm_classifier.predict(title_vectorized)

#     # Return the predicted sentiment
#     return prediction[0]

# # Function to fetch the 10 newest articles for each publication and predict sentiment
# def predict_sentiment_for_newest_articles():
#     # Dictionary to store sentiment predictions for each publication
#     publication_sentiments = {}

#     # Fetch unique publication names from the database
#     cursor.execute("SELECT DISTINCT name FROM news_items")
#     publications = cursor.fetchall()

#     # Iterate over each publication
#     for publication in publications:
#         publication_name = publication[0]

#         # Fetch the 10 newest articles for the current publication
#         cursor.execute("SELECT title FROM news_items WHERE name=? ORDER BY published_at DESC LIMIT 10", (publication_name,))
#         articles = cursor.fetchall()

#         # List to store sentiment predictions for the current publication
#         publication_sentiments[publication_name] = []

#         # Iterate over each article and predict sentiment
#         for article in articles:
#             title = article[0]
#             sentiment = predict_sentiment(title)
#             publication_sentiments[publication_name].append((title, sentiment))

#     return publication_sentiments

# # Predict sentiment for the 10 newest articles for each publication
# publication_sentiments = predict_sentiment_for_newest_articles()

# # Print sentiment predictions for each publication
# for publication, articles in publication_sentiments.items():
#     print("Publication:", publication)
#     for title, sentiment in articles:
#         print("Title:", title)
#         print("Sentiment:", sentiment)
#     print()

# %%
# import os
# from together import Together

# import requests

# endpoint = 'https://api.together.xyz/inference'
# TOGETHER_API_KEY = os.getenv('TOGETHER_API_KEY')

# res = requests.post(endpoint, json={
#     "model": 'meta-llama/Llama-3-70b-chat-hf',
#     "prompt": """\
#       Label the sentences as either "Positive", "Negative" or "Neutral":

#       Sentence: I can say that there isn't anything I would change.
#       Label: Positive

#       Sentence: I'm not sure about this.
#       Label: Neutral

#       Sentence: I think the background image could have been better.
#       Label: Negative

#       Sentence: I really like it.
#       Label:""",
#     "top_p": 1,
#     "top_k": 40,
#     "temperature": 0.8,
#     "max_tokens": 1,
#     "repetition_penalty": 1,
# }, headers={
#     "Authorization": f"Bearer {TOGETHER_API_KEY}",
#     "User-Agent": "<YOUR_APP_NAME>"
# })
# print(res.json()['output']['choices'][0]['text']) # ' positive'
# Out:
#  Sentence

# %%
# import os
# import requests
# import pandas as pd
# import sqlite3
# import pickle

# # Define the setup function
# def setup():
#     # Load your trained SVM model
#     with open("svm_classifier.pkl", "rb") as f:
#         svm_classifier = pickle.load(f)

#     # Load the TF-IDF vectorizer
#     with open("tfidf_vectorizer.pkl", "rb") as f:
#         vectorizer = pickle.load(f)

#     # Connect to SQLite database
#     conn = sqlite3.connect("news_database.db")
#     cursor = conn.cursor()

#     return svm_classifier, vectorizer, cursor

# # Call the setup function to get SVM classifier, TF-IDF vectorizer, and cursor
# svm_classifier, vectorizer, cursor = setup()

# # Function to predict sentiment for a given title using the SVM model
# def predict_sentiment_svm(title):
#     # Vectorize the title
#     title_vectorized = vectorizer.transform([title])

#     # Make prediction using SVM classifier
#     prediction = svm_classifier.predict(title_vectorized)

#     # Return the predicted sentiment
#     return prediction[0]

# # Function to predict sentiment for a given title using the Together model
# def predict_sentiment_together(title):
#     # Define the prompt
#     prompt = f"Label the sentence as either 'Positive', 'Negative', or 'Neutral':\n\nSentence: {title}\nLabel:"

#     # Make request to Together API
#     endpoint = 'https://api.together.xyz/inference'
#     TOGETHER_API_KEY = os.getenv('TOGETHER_API_KEY')

#     res = requests.post(endpoint, json={
#         "model": 'meta-llama/Llama-3-70b-chat-hf',
#         "prompt": prompt,
#         "top_p": 1,
#         "top_k": 40,
#         "temperature": 0.8,
#         "max_tokens": 1,
#         "repetition_penalty": 1,
#     }, headers={
#         "Authorization": f"Bearer {TOGETHER_API_KEY}",
#         "User-Agent": "<YOUR_APP_NAME>"
#     })

#     # Extract sentiment from response
#     sentiment = res.json()['output']['choices'][0]['text'].strip().lower()

#     return sentiment

# # Function to fetch the 10 newest articles for each publication and predict sentiment using both models
# def predict_sentiment_for_newest_articles():
#     # Dictionary to store sentiment predictions for each publication
#     publication_sentiments = {}

#     # Fetch unique publication names from the database
#     cursor.execute("SELECT DISTINCT name FROM news_items")
#     publications = cursor.fetchall()

#     # Iterate over each publication
#     for publication in publications:
#         publication_name = publication[0]

#         # Fetch the 10 newest articles for the current publication
#         cursor.execute("SELECT title FROM news_items WHERE name=? ORDER BY published_at DESC LIMIT 10", (publication_name,))
#         articles = cursor.fetchall()

#         # List to store sentiment predictions for the current publication using both models
#         publication_sentiments[publication_name] = []

#         # Iterate over each article and predict sentiment using both models
#         for article in articles:
#             title = article[0]
#             sentiment_svm = predict_sentiment_svm(title)
#             sentiment_together = predict_sentiment_together(title)
#             publication_sentiments[publication_name].append((title, sentiment_svm, sentiment_together))

#     return publication_sentiments

# # Predict sentiment for the 10 newest articles for each publication using both models
# publication_sentiments = predict_sentiment_for_newest_articles()

# # Print sentiment predictions for each publication
# for publication, articles in publication_sentiments.items():
#     print("Publication:", publication)
#     for title, sentiment_svm, sentiment_together in articles:
#         print("Title:", title)
#         print("Sentiment (SVM):", sentiment_svm)
#         print("Sentiment (Together):", sentiment_together)
#     print()

# %%
import os
import requests
import pandas as pd
import sqlite3
import pickle

# Define the setup function
def setup():
    # Load your trained SVM model
    with open("svm_classifier.pkl", "rb") as f:
        svm_classifier = pickle.load(f)

    # Load the TF-IDF vectorizer
    with open("tfidf_vectorizer.pkl", "rb") as f:
        vectorizer = pickle.load(f)

    # Connect to SQLite database
    conn = sqlite3.connect("news_database.db")
    cursor = conn.cursor()

    return svm_classifier, vectorizer, cursor

# Call the setup function to get SVM classifier, TF-IDF vectorizer, and cursor
svm_classifier, vectorizer, cursor = setup()

# Function to predict sentiment for a given title using the SVM model
def predict_sentiment_svm(title):
    # Vectorize the title
    title_vectorized = vectorizer.transform([title])

    # Make prediction using SVM classifier
    prediction = svm_classifier.predict(title_vectorized)

    # Return the predicted sentiment (capitalized)
    return prediction[0].capitalize()

# Function to predict sentiment for a given title using the Together model
def predict_sentiment_together(title):
    # Define the prompt
    prompt = f"Label the sentence as either 'Positive', 'Negative', or 'Neutral':\n\nSentence: {title}\nLabel:"

    # Make request to Together API
    endpoint = 'https://api.together.xyz/inference'
    TOGETHER_API_KEY = os.getenv('TOGETHER_API_KEY')

    res = requests.post(endpoint, json={
        "model": 'meta-llama/Llama-3-70b-chat-hf',
        "prompt": prompt,
        "top_p": 1,
        "top_k": 40,
        "temperature": 0.8,
        "max_tokens": 1,
        "repetition_penalty": 1,
    }, headers={
        "Authorization": f"Bearer {TOGETHER_API_KEY}",
        "User-Agent": "<YOUR_APP_NAME>"
    })

    # Extract sentiment from response
    sentiment = res.json()['output']['choices'][0]['text'].strip().capitalize()

    return sentiment

# Function to fetch the 10 newest articles for each publication and predict sentiment using both models
def predict_sentiment_for_newest_articles():
    # Dictionary to store sentiment predictions for each publication
    publication_sentiments = {}

    # Fetch unique publication names from the database
    cursor.execute("SELECT DISTINCT name FROM news_items")
    publications = cursor.fetchall()

    # Iterate over each publication
    for publication in publications:
        publication_name = publication[0]

        # Fetch the 10 newest articles for the current publication
        cursor.execute("SELECT title FROM news_items WHERE name=? ORDER BY published_at DESC LIMIT 10", (publication_name,))
        articles = cursor.fetchall()

        # List to store sentiment predictions for the current publication using both models
        publication_sentiments[publication_name] = []

        # Iterate over each article and predict sentiment using both models
        for article in articles:
            title = article[0]
            sentiment_svm = predict_sentiment_svm(title)
            sentiment_together = predict_sentiment_together(title)
            publication_sentiments[publication_name].append((title, sentiment_svm, sentiment_together))

    return publication_sentiments

# Predict sentiment for the 10 newest articles for each publication using both models
publication_sentiments = predict_sentiment_for_newest_articles()

# Print sentiment predictions for each publication
for publication, articles in publication_sentiments.items():
    print("Publication:", publication)
    for title, sentiment_svm, sentiment_together in articles:
        print("Title:", title)
        print("Sentiment (SVM):", sentiment_svm)
        print("Sentiment (Together):", sentiment_together)
    print()
# Out:
# Publication: Associated Press
# Title: Tensions grips UCLA campus after police order protestors to disperse or face arrest - The Associated Press
# Sentiment (SVM): Negative
# Sentiment (Together): Negative
# Title: Colombia's president says country will break diplomatic relations with Israel over war in Gaza - The Associated Press
# Sentiment (SVM): Negative
# Sentiment (Together): Negative
# Title: Ex-Nickelodeon producer Schneider sues 'Quiet on Set' makers for defamation and sex abuse implications - The Associated Press
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Blinken presses Hamas to seal cease-fire with Israel, says 'the time is now' for a deal - The Associated Press
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Arizona Senate OKs bill to repeal the state's 1864 near-total abortion ban - The Associated Press
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: United Methodists repeal longstanding ban on LGBTQ clergy - The Associated Press
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: Election 2024: Trump returns to campaign facing jail warning - The Associated Press
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
# Title: Mammograms should start at 40 to address rising breast cancer rates at younger ages, panel says - The Associated Press
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
#
# Publication: CNN
# Title: Noem suggests Biden’s dog Commander should suffer a similar fate to Cricket, the dog she shot
# Sentiment (SVM): Negative
# Sentiment (Together): Negative
# Title: Fifth body recovered from Baltimore bridge collapse site - CNN
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
# Title: Task force updates guidance for breast cancer screenings for women 40 and older - CNN
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Police on campus at Columbia and UCLA as protests disrupt colleges nationwide: Live updates - CNN
# Sentiment (SVM): Negative
# Sentiment (Together): Neutral
#
# Publication: BBC News
# Title: Scarlett Johansson's AI row has echoes of Silicon Valley's bad old days
# Sentiment (SVM): Negative
# Sentiment (Together): Negative
# Title: PSNI could be fined £750k over data breach
# Sentiment (SVM): Negative
# Sentiment (Together): Negative
# Title: Bus crash leaves at least five children injured
# Sentiment (SVM): Negative
# Sentiment (Together): Negative
# Title: How does the UK compare with other economies?
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Voters ‘distraught’ by direction of Conservatives, say Greens
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
# Title: Austrian man discovers mammoth bones in wine cellar
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: 'Missed opportunities' to prevent paedophile's murder
# Sentiment (SVM): Negative
# Sentiment (Together): Negative
# Title: Watch: Rishi Sunak's election announcement in full
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Sunak announces UK general election for 4 July
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Tatler Kate portrait prompts strong reaction online
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
#
# Publication: CNBC
# Title: Moderna loses less than expected as Covid vaccine sales beat estimates, cost cuts take hold - CNBC
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: Stock futures rise after Fed decides to hold rates steady: Live updates - CNBC
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Long-predicted consumer pullback finally hits restaurants like Starbucks, KFC and McDonald's - CNBC
# Sentiment (SVM): Positive
# Sentiment (Together): Negative
#
# Publication: Fox News
# Title: Harvey Weinstein faces new trial after rape conviction overturned, returns to prison - Fox News
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
# Title: Volunteer searchers claim to have found secret crematorium in Mexico City - Fox News
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Melissa McCarthy reacts to Barbra Streisand's awkward question about Ozempic - Fox News
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
#
# Publication: Federalreserve.gov
# Title: Federal Reserve issues FOMC statement - Federal Reserve
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
#
# Publication: ABC News
# Title: Climber found dead after falling off highest peak in North America
# Sentiment (SVM): Negative
# Sentiment (Together): Negative
# Title: Minors again found working at Alabama poultry plant where 16-year-old died, DOL says
# Sentiment (SVM): Negative
# Sentiment (Together): Negative
# Title: 35-year-old man survives grizzly bear attack after encountering 2 at national park
# Sentiment (SVM): Negative
# Sentiment (Together): Positive
# Title: Hearing to determine if Missouri man who has been in prison for 33 years was wrongfully convicted
# Sentiment (SVM): Negative
# Sentiment (Together): Neutral
# Title: American mistakenly accused of involvement in DRC coup attempt
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
# Title: Trump posts social media clip seemingly suggesting a win will bring 'unified Reich'
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
# Title: Austin says 'expectation' is Ukraine won't use US weapons outside its territory
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: WATCH: Bear finds nothing to eat in Florida garage fridge
# Sentiment (SVM): Negative
# Sentiment (Together): Neutral
# Title: Prosecutor in Hunter Biden case plans to call ex-wife, brother's widow as witnesses
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Moose kills Alaska man attempting to take photos of her newborn calves
# Sentiment (SVM): Negative
# Sentiment (Together): Negative
#
# Publication: The Wall Street Journal
# Title: Tesla Is Pulling Back From EV Charging, and People Are Freaking Out - The Wall Street Journal
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
#
# Publication: Politico
# Title: Has the DeSantis comeback already begun? - POLITICO - POLITICO
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Officials warn of risks to 'certain groups' of people amid bird flu outbreak in cows - POLITICO
# Sentiment (SVM): Negative
# Sentiment (Together): Negative
# Title: RFK Jr. is all over conservative media. Trump's camp is concerned. - POLITICO
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
#
# Publication: CBS Sports
# Title: NFL Power Rankings: Bengals, Jets rise with Joe Burrow, Aaron Rodgers back; stagnant Cowboys drop from top 10 - CBS Sports
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
#
# Publication: New York Post
# Title: Ryan Garcia tested positive for PED before his win over Devin Haney - New York Post
# Sentiment (SVM): Positive
# Sentiment (Together): Negative
# Title: Prince William shares health update on Kate Middleton after her cancer diagnosis - New York Post
# Sentiment (SVM): Negative
# Sentiment (Together): Neutral
# Title: Tyrese Maxey wrecked Knicks' celebrity row: Tracy Morgan middle finger, 'seething' Ben Stiller and a Jon Stewart meme - New York Post
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
#
# Publication: Ars Technica
# Title: Netflix releases first look at new Witcher after Henry Cavill left for Warhammer 40K
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Here’s what’s really going on inside an LLM’s neural network
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: A week with the Chevy Blazer EV shows things to love—but also painful flaws
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
# Title: The first crew launch of Boeing’s Starliner capsule is on hold indefinitely
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
# Title: Anti-pasteurization crowd reaffirms love of raw milk despite bird flu outbreak
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
# Title: Disarmingly lifelike: ChatGPT-4o will laugh at your jokes and your dumb hat
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Krysten Ritter has lost her memories in trailer for Orphan Black: Echoes
# Sentiment (SVM): Negative
# Sentiment (Together): Neutral
# Title: ChatGPT-4o allows real-time audio-video conversations with an “emotional” AI chatbot
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: Elon Musk’s X dodges Australian order to remove church stabbing video
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
# Title: Beethoven likely didn’t die from lead poisoning, new DNA analysis reveals
# Sentiment (SVM): Negative
# Sentiment (Together): Neutral
#
# Publication: The Verge
# Title: OpenAI’s News Corp deal licenses content from WSJ, New York Post, and more
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Political ads could require AI-generated content disclosures soon
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Lawmakers debate ending Section 230 in order to save it
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Big Tech thinks it can plant trees better than everyone else
# Sentiment (SVM): Positive
# Sentiment (Together): Negative
# Title: Meta’s Ray-Ban glasses will post Instagram stories for you
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Super Mario Maker 64 exists, thanks to a new ROM hack
# Sentiment (SVM): Positive
# Sentiment (Together): Positive
# Title: Reddit’s deal with OpenAI will plug its posts into ‘ChatGPT and new products’
# Sentiment (SVM): Positive
# Sentiment (Together): Neutral
# Title: The Mac vs. PC war is back on
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: X-Men ‘97 understood the power of perfect timing
# Sentiment (SVM): Positive
# Sentiment (Together): Positive
# Title: Nicolas Cage is back as Spider-Man in live-action Amazon series
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
#
# Publication: National Institutes of Health
# Title: Endurance exercise affects all tissues of the body, even those not normally associated with movement - National Institutes of Health (NIH) (.gov)
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
#
# Publication: Futurism
# Title: China Releases CGI Video of Moon Base and It Contains Something Very Strange - Futurism
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
#
# Publication: PBS
# Title: What reclassifying marijuana means for Americans - PBS NewsHour
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
#
# Publication: Axios
# Title: J&J baby powder settlement: Johnson & Johnson agrees to new $6.5B deal - Axios
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
#
# Publication: Lanl.gov
# Title: New findings point to an Earth-like environment on ancient Mars - Discover LANL
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
#
# Publication: Road to VR
# Title: ‘Batman: Arkham Shadow’ Announced Exclusively for Quest 3 From Meta-owned Studio Behind ‘Iron Man VR’ - Road to VR
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
#
# Publication: Yahoo Entertainment
# Title: Snap brings its AR lenses to Chrome through an extension
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: There’s a new Vision show coming to Disney+ with Paul Bettany
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: Starliner’s first crew mission gets pushed back yet again, this time with no new launch date
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
# Title: Sure, why not: China built a chatbot based on Xi Jinping
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: Anker power banks are up to half off ahead of Memorial Day weekend
# Sentiment (SVM): Positive
# Sentiment (Together): Positive
# Title: Marvel's What If...? for Apple Vision Pro gets a trailer and release date
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Emory University awarded two students $10,000 for their AI study tool, then suspended them
# Sentiment (SVM): Negative
# Sentiment (Together): Negative
# Title: Nintendo snaps up a studio known for its Switch ports
# Sentiment (SVM): Positive
# Sentiment (Together): Positive
# Title: Japanese town overrun with tourists puts up view-blocking barrier near Mount Fuji
# Sentiment (SVM): Negative
# Sentiment (Together): Negative
# Title: Ukraine firefighters tackle flames in Kharkiv after Russia carries out another strike on city
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
#
# Publication: cleveland.com
# Title: LeBron James addresses NBA future after Los Angeles Lakers playoff exit - cleveland.com
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
#
# Publication: The Washington Post
# Title: May night sky begins with Eta Aquariid meteor shower - The Washington Post
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
#
# Publication: TechRadar
# Title: The Galaxy Watch Ultra is spotted again as Samsung hints at 'premium' smartwatches - TechRadar
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
#
# Publication: NDTV News
# Title: After Maldives, Another Island Nation Elects Pro-China PM - Off Australia - NDTV
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
#
# Publication: USA Today
# Title: Body camera footage captures first responders' reactions in wake of Baltimore bridge collapse
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Body camera footage captures first responders' reactions in wake of Baltimore bridge collapse
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Police officers, guns, and community collide: How the Charlotte house shooting happened - USA TODAY
# Sentiment (SVM): Negative
# Sentiment (Together): Neutral
#
# Publication: NBC News
# Title: Arizona abortion ban fight jolts packed GOP House primary - NBC News
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
#
# Publication: Space.com
# Title: Here's what to expect during Boeing Starliner's 1st astronaut test flight on May 6 - Space.com
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Watch SpaceX's Crew-8 astronauts move their Dragon at the ISS May 2 to make way for Boeing's Starliner - Space.com
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
#
# Publication: CBS News
# Title: Antisemitism Awareness Act passes House vote. Here's what the bill does. - CBS New York
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
#
# Publication: NPR
# Title: Nikki Haley says she'll vote for Trump
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: After years in decline, U.S. drowning deaths are rising again
# Sentiment (SVM): Negative
# Sentiment (Together): Negative
# Title: Lack of staffing led to 'deeply concerning' conditions at federal prison in Oregon
# Sentiment (SVM): Negative
# Sentiment (Together): Negative
# Title: The MacArthur Foundation wants bold solutions to big problems — the prize is $100M
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: Ireland, Norway, Spain to recognize a Palestinian state; stay safe during turbulence
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Buy-now, pay-later returns and disputes are about to get federal oversight
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
# Title: Stephen King's new story took him 45 years to write. He tells NPR why
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: A big survey asked Americans about their finances. Here are some trouble spots
# Sentiment (SVM): Negative
# Sentiment (Together): Neutral
# Title: 6 key facts about abortion laws and the 2024 election
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Norway, Ireland and Spain say they will recognize a Palestinian state
# Sentiment (SVM): Negative
# Sentiment (Together): Positive
#
# Publication: Daily Beast
# Title: Trump Piles on Hush-Money Judge After Jail Time Warning - The Daily Beast
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
#
# Publication: Sportsnet.ca
# Title: Oilers’ special teams, top players too much for outmatched Kings in Round 1 - Sportsnet.ca
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
#
# Publication: ESPN
# Title: Mavs' Luka Doncic dominates Game 5 despite illness, knee injury - ESPN
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
#
# Publication: ScienceAlert
# Title: Curiosity Detects 'Habitable' Earth-Like Past on Mars, But How Did Oxygen Get There? - ScienceAlert
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
#
# Publication: NBCSports.com
# Title: Ezekiel Elliott on return to Cowboys: I'm here to chase a dream - NBC Sports
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
#
# Publication: WKOW
# Title: Mount Horeb police shoot, kill student with gun outside middle school - WKOW
# Sentiment (SVM): Negative
# Sentiment (Together): Negative
#
# Publication: Fortune
# Title: Bird flu in Texas has spread to some workers - Fortune
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
#
# Publication: Lifehacker.com
# Title: Google Phone's New Audio Emojis for Android Include a Fart Button - Lifehacker
# Sentiment (SVM): Positive
# Sentiment (Together): Neutral
#
# Publication: GameSpot
# Title: Stay At The X-Mansion With AirBnb, Danger Room Included - GameSpot
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
#
# Publication: Dark Horizons
# Title: "Batman: Arkham Shadow" VR Game Trailer - Dark Horizons
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
#
# Publication: Inverse
# Title: Chrome's New Built-in AI Is The Biggest Update To the Browser In Over 15 Years - Inverse
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
#
# Publication: NASA
# Title: What's Up: May 2024 Skywatching Tips from NASA - Science@NASA
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
#
# Publication: Cdc.gov
# Title: Preventable Premature Deaths from the Five Leading Causes of Death in Nonmetropolitan and Metropolitan Counties, United States, 2010–2022 | MMWR - CDC
# Sentiment (SVM): Negative
# Sentiment (Together): Neutral
#
# Publication: Wired
# Title: How to Clear Your Browser's Cache, and Why You Should
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: What Scarlett Johansson v. OpenAI Could Look Like in Court
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Local Coworking Spaces Thrive Where WeWork Dared Not Go
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: We Stood on Both Sides of the New York–Dublin Portal and It Was Glorious
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: /e/OS Review: This Operating System Is Better Than Android. You Should Try It
# Sentiment (SVM): Positive
# Sentiment (Together): Positive
# Title: A Far-Right Indian News Site Posts Racist Conspiracies. US Tech Companies Keep Platforming It
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
# Title: Neuralink’s First User Is ‘Constantly Multitasking’ With His Brain Implant
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: The World Is Ignoring the Other Deadly Kind of Carbon
# Sentiment (SVM): Negative
# Sentiment (Together): Negative
# Title: The Complex Social Lives of Viruses
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Razer Fujin Pro Gaming Chair Review: Giving My Back an Extra Life
# Sentiment (SVM): Positive
# Sentiment (Together): Positive
#
# Publication: Gizmodo.com
# Title: 10 Standout Sci-Fi, Horror, and Fantasy Series on Max
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: James Wan Wants to Bring Back The Munsters for Universal's Monsterverse
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: Human Infected With Bird Flu in Michigan, Only the Second Case of Current Outbreak
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
# Title: Predator and Black Panther Will Collide in a New Marvel Mini-Series
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: Electric Vehicles Are More Likely to Hit Pedestrians Than Gas Cars Are, Study Finds
# Sentiment (SVM): Negative
# Sentiment (Together): Negative
# Title: Groundbreaking Measurement Reveals a Black Hole Spinning at a Quarter the Speed of Light
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: Marvel's Upcoming What If? VR Game Gets a Revealing First Trailer
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: Alexa Will Get an Upgrade But It'll Cost You, Report Says
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
# Title: OpenAI Unveils GPT-4 Omni’s Voice Capabilities and They’re Literally Unbelievable
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: Canadian Wildfire Smoke Blows Into U.S., Setting Stage for Another Miserable Summer
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
#
# Publication: InsideClimate News
# Title: Storing energy with compressed air is about to have its moment of truth
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
#
# Publication: Seths.blog
# Title: “I don’t learn that way”
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
# Title: Pet quirks
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: The strategy sessions
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: The strategy sessions
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: The defensive arrogance of TL;DR
# Sentiment (SVM): Neutral
# Sentiment (Together): ?
# Title: The half-life of magic
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: She’s here!
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: Don’t rush
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Beyond CRM
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: The other choices
# Sentiment (SVM): Negative
# Sentiment (Together): Neutral
#
# Publication: Android Central
# Title: Our favorite phone of 2024 (so far) just scored a HUGE discount during Amazon's Memorial Day sale
# Sentiment (SVM): Positive
# Sentiment (Together): Positive
# Title: A cleaner Google Messages text field rolls out to more users
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: Galaxy Z Flip 6, Fold 6 might drop Exynos for the Snapdragon 8 Gen 3 'exclusively'
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: The Google Gemini app still isn't available for some phones. Why not?
# Sentiment (SVM): Negative
# Sentiment (Together): Negative
# Title: Wearable AI brand Humane looking to sell, sources say
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Ray-Ban Meta AI and more looks to be coming to Quest soon
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: OpenAI trying to steal Scarlett Johansson's voice to make AI feel 'comfortable' is the reason why it's so worrying
# Sentiment (SVM): Negative
# Sentiment (Together): Negative
# Title: First 12 things to do with the Pixel 8a
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Google Play Points introduces new features to enhance user rewards
# Sentiment (SVM): Positive
# Sentiment (Together): Positive
# Title: Honor's upcoming smartphones will include Google's generative AI features
# Sentiment (SVM): Positive
# Sentiment (Together): Positive
#
# Publication: MacRumors
# Title: Apple's 2024 M4 Mac Mini: What We Know
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: What the Golf on Apple Vision Pro Gains New Levels
# Sentiment (SVM): Positive
# Sentiment (Together): Positive
# Title: Best M4 iPad Pro Cases Currently Available
# Sentiment (SVM): Positive
# Sentiment (Together): Positive
# Title: Apple Music Reveals Top 10 Albums of All Time
# Sentiment (SVM): Positive
# Sentiment (Together): Positive
# Title: Apple Adds Support for Live Activities to Shazam
# Sentiment (SVM): Positive
# Sentiment (Together): Positive
# Title: iOS 17.5 Features: What's New in iOS 17.5
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Setapp's EU Alternative iPhone App Marketplace Launching on May 14
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: iPad Marketing VP: iPad and Mac are Complementary Devices, Not Competing Devices
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: HDR Bug Impacts OLED iPad Pro, Apple Working on Software Fix
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: M2 iPad Air Reviews: A Larger Display at a More Affordable Price
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
#
# Publication: CNET
# Title: Here's How Much It Costs to Have Groceries Delivered Versus Buying In Person - CNET
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Bill Gates Wants You to Stream This One Show on Apple TV Plus - CNET
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: Snag the Fire TV Stick 4K Max for the Low Price of $40, Fire TV Stick Lite for Just $20 and More - CNET
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: How to Return Your Amazon Products for Free - CNET
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: She Found Financial Freedom After Dumping Her Spouse, House and Job - CNET
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: T-Mobile Is Raising Prices on Some of Its Older Plans, Starting With Your Next Bill - CNET
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
# Title: Best Grill and Smoker Deals for Memorial Day: Save on Traeger, Nexgrill and more - CNET
# Sentiment (SVM): Positive
# Sentiment (Together): Neutral
# Title: You Can Bag Apple's M1 24-inch iMac for Just $750, But You'll Need to Be Quick - CNET
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: Memorial Day Weekend: Your Ultimate Travel Checklist for a Stress-Free Trip - CNET
# Sentiment (SVM): Positive
# Sentiment (Together): Neutral
# Title: 'Evil' Season 4: What to Remember Before Streaming the Final Season - CNET
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
#
# Publication: Business Insider
# Title: Some central banks have sold gold at record prices, cashing in on the global boom
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: Interest rates are still sky-high — but companies aren't feeling the squeeze
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Former Google employee says company's AI work is driven by 'a stone cold panic that they are getting left behind'
# Sentiment (SVM): Negative
# Sentiment (Together): Negative
# Title: Google Earth lets you explore the world via satellite images on a 3D globe. Here's how to use it and make custom maps.
# Sentiment (SVM): Positive
# Sentiment (Together): Neutral
# Title: A rare feather just sold for $28,000, making it worth 40 times as much as gold by weight
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: It's so tough to pay cash in China that the government had to fine a KFC for not accepting banknotes
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: FDIC chairman Martin Gruenberg to resign following investigations into sexual harassment at the bank regulator
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
# Title: Elon Musk is mourning the loss of Red Lobster too
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Trump Media lost $327 million last quarter. It's still valued at more than $6 billion.
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
# Title: Tesla is turning on the charm after leasing and rental-car companies say the value of their fleets have plummeted, but it may not be enough: report
# Sentiment (SVM): Negative
# Sentiment (Together): Neutral
#
# Publication: Slashdot.org
# Title: Vitalik Buterin Addresses Threats To Ethereum's Decentralization In New Blog Post
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Linux Kernel 6.9 Officially Released
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: Linux Kernel 6.9 Officially Released
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: Reddit Grows, Seeks More AI Deals, Plans 'Award' Shops, and Gets Sued
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Reddit Grows, Seeks More AI Deals, Plans 'Award' Shops, and Gets Sued
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Could Atomically Thin Layers Bring A 19x Energy Jump In Battery Capacitors?
# Sentiment (SVM): Negative
# Sentiment (Together): Positive
# Title: Could Atomically Thin Layers Bring A 19x Energy Jump In Battery Capacitors?
# Sentiment (SVM): Negative
# Sentiment (Together): Positive
# Title: Father of SQL Says Yes to NoSQL
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: Father of SQL Says Yes to NoSQL
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Former Boeing Quality Inspector Turns Whistleblower, Says Plane Parts Had Serious Defects
# Sentiment (SVM): Negative
# Sentiment (Together): Negative
#
# Publication: ReadWrite
# Title: Dogecoin Maxi DonAlt Posts $1 Price Prediction – Risk On For Meme Coins?
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: CSOP Plus May 5-26 Tournament Series Starts On CoinPoker App
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: Meme Coin Price Predictions As Market Recovers – WIF, BONK, SHIB
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Google Pixel 9: Release date, specs, price and everything we know so far
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Ukraine introduces AI-generated spokesperson for its foreign ministry
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: The Best Fallout 4 VR Mods to make you think you are actually in the show
# Sentiment (SVM): Positive
# Sentiment (Together): Positive
#
# Publication: Kotaku
# Title: Senua’s Saga: Hellblade II: The Kotaku Review
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Stellar Blade's 'Censorship' Circus, Remembering The First Sonic Trailer Five Years Later, And More Of The Week's Gaming Opinions
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
#
# Publication: Hipertextual
# Title: HBO pasa a ser Max y actualiza sus precios: ¿cuánto pagarás a partir de ahora?
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Max llega a España: estas son las diferencias de catálogo con HBO
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Microsoft usará la IA de GPT-4o para ayudarte a jugar ‘Minecraft’
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: 5 joyas clásicas en Max que puedes ver ahora mismo
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: 5 joyas clásicas en Max que puedes ver ahora mismo
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: 5 historias de terror geniales para ver en Star+
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: 5 historias de terror geniales para ver en Star+
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Las 5 películas imprescindibles de Netflix
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: Las 5 películas imprescindibles de Netflix
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: 3 cosas en las que falla ‘Rebel Moon (Parte dos): La guerrera que deja marcas’
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
#
# Publication: Hackaday
# Title: Quad-Motor Electric Kart Gets A Little Too Thrilling
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: Home Assistant Display Uses E-Ink
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Pi Pico Helps Restring Badminton Rackets
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: Hackaday Links: May 12, 2024
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Hackaday Links: May 12, 2024
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Autochrome For The 2020s
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Autochrome For The 2020s
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: IRCB S73-7 Satellite Found After Going Untracked For 25 Years
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: IRCB S73-7 Satellite Found After Going Untracked For 25 Years
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: JTAG Hacking An SSD With A Pi: A Primer
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
#
# Publication: Xkcd.com
# Title: Exponential Growth
# Sentiment (SVM): Positive
# Sentiment (Together): Neutral
# Title: Driving PSA
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Chasing
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Google Solar Cycle
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Good and Bad Ideas
# Sentiment (SVM): Negative
# Sentiment (Together): Neutral
# Title: Software Testing Day
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
#
# Publication: Fort Worth Star-Telegram
# Title: Flash flood warning issued for Collin and Denton counties until early Sunday morning, according to the NWS
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
#
# Publication: Kansas City Star
# Title: ‘Precious’ puppy found malnourished and abandoned in porta-potty rescued by shelter
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
#
# Publication: WPIX 11 New York
# Title: Boeing is on the verge of launching astronauts into space in new capsule
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
#
# Publication: Makezine.com
# Title: Mobile Mojo Mastery using Wireless Desktop CNC
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Making Makers: Building Makerspaces in K–12 Parochial Schools
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
#
# Publication: The Daily Meal
# Title: The Ultimate Ranking Of Canned Roast Beef, According To Customer Reviews
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: The Ultimate Ranking Of Canned Roast Beef, According To Customer Reviews
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
#
# Publication: Fall River Herald News
# Title: Lafayette Park pool renovations to close lane on Eastern Avenue: What you need to know
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Lafayette Park pool renovations to close lane on Eastern Avenue: What you need to know
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
#
# Publication: Time
# Title: Horizon Is More a Tribute to Great Westerns Than a Great One Itself
# Sentiment (SVM): Positive
# Sentiment (Together): Negative
# Title: Trump Media and Technology Group Posts Over $300M Net Loss in First Public Quarter
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
# Title: Moose Kills Alaska Man Attempting to Take Photos of Her Calves
# Sentiment (SVM): Negative
# Sentiment (Together): Negative
# Title: Boredom Makes Us Human
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: Boredom Makes Us Human
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
#
# Publication: Xataka.com
# Title: Max ya está aquí: todas las diferencias con HBO Max y las novedades que trae la nueva plataforma de Warner
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Scarlett Johansson, "enfadada e incrédula" por el parecido de la voz de ChatGPT con la suya. No le sirve la respuesta de OpenAI
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
# Title: Microsoft persigue el sueño de tener su propio MacBook Air con los PCs Copilot+. Es el intento más convincente que recordamos
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: Los mejores descuentos en dispositivos Xiaomi los tienes en Powerplanet: ahorro para gamers, melómanos o internautas
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: Tras el boom del alquiler vacacional, llega el del alquiler de piscinas: se expande y ya deja sobresueldos de 10.000 euros
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: Copilot+ llega a un arsenal de nuevos portátiles: Acer, ASUS, Dell, HP, Lenovo y Samsung se apuntan a lo último de Qualcomm y Microsoft
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: La Redmi Pad Pro es la nueva tablet calidad-precio de Xiaomi: sus características son un espectáculo
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
#
# Publication: Cool Hunting
# Title: iF Design’s 2024 Trend Report and Conference
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
#
# Publication: Le Monde
# Title: Trois recettes légères et pas chères du petit-déjeuner au dîner
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: La campagne de Donald Trump attaquée pour une vidéo mentionnant un « Reich unifié »
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
# Title: En direct, guerre en Ukraine : « Nous gardons le contrôle partout », assure Volodymyr Zelensky
# Sentiment (SVM): Neutral
# Sentiment (Together): Ne
# Title: Sur Parcoursup, des candidats en réorientation désavantagés : « Un parcours non linéaire et des hésitations sont considérés comme suspects »
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
#
# Publication: IGN
# Title: Kingdom Hearts Series Coming to Steam Next Month
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
#
# Publication: Digital Trends
# Title: SpaceX photos show important Starship pre-flight rehearsal
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
#
# Publication: Pcloadletter.dev
# Title: The ChatGPT wrapper product boom is an uncanny valley hellscape
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
#
# Publication: Bumblemeow.com
# Title: Comparing desktop development tools, Qt, Electron and macOS Native
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
#
# Publication: Proton.me
# Title: How (and why) to de-Google your life and protect your privacy
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
#
# Publication: Andymatuschak.org
# Title: How Might We Learn?
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
#
# Publication: Whatheco.de
# Title: CamelCase vs. Snake_case Scientific Studies
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
#
# Publication: Substack.com
# Title: The OpenAI board was right – No (by a voice actres named Scarlet) means No
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
#
# Publication: Stripe.com
# Title: Stripe increasing "instant payout" fees by 50%
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
#
# Publication: Tomblomfield.com
# Title: Taking Risk – Startups in UK vs. US
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
#
# Publication: Arxiv.org
# Title: Chameleon: Meta's New Multi-Modal LLM
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
#
# Publication: N8s.site
# Title: Async Rust Isn't Bad: You Are
# Sentiment (SVM): Negative
# Sentiment (Together): Neutral
#
# Publication: Modos.tech
# Title: Modos Paper Monitor Pre-Launch on Crowd Supply
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
#
# Publication: Gigazine.net
# Title: Metaがインドの選挙期間中に偽情報や暴力を扇動するAIが生成した画像を含むFacebook広告を承認していたことが判明
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
# Title: Microsoftが「第11世代Surface Pro」と「第7世代Surface Laptop」を発表、Snapdragon X Elite／Plus搭載でAI処理に最適
# Sentiment (SVM): Positive
# Sentiment (Together): Positive
# Title: ガラパゴスに行かずとも大量のイグアナに会えるタークス・カイコスのリトル・ウォーター・ケイに行ってみた【インターリンク ドメイン島巡り 第45回「.tc」】
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
#
# Publication: Blogger.com
# Title: "Mortgage Rates Close Enough to Unchanged Over The Weekend"
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
#
# Publication: heise online
# Title: heise+ | Marktübersicht: KI-Server mit GPUs im Überblick
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Video: Ist die perfekte DIY-Schleifmaschine möglich?
# Sentiment (SVM): Negative
# Sentiment (Together): Neutral
# Title: Photovoltaik: China baut größtes Offshore-Solarkraftwerk der Welt
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: Vor Jahren gelöschte iPhone-Fotos kehren zurück: iOS 17.5.1 soll Bug beseitigen
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: heise-Angebot: iX-Workshop IEC 62443: IT-Sicherheit in der Produktentwicklung
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Kryptogeldbetrug über eine Milliarde US-Dollar: Genesis zahlt zwei Milliarden
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
# Title: heise+ | Growboxen ausprobiert: Digital unterstützte Anzuchtboxen für den Cannabis-Anbau
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Title: Wieder Brand durch E-Bike-Akku: Feuerwehr warnt vor dem Laden in der Wohnung
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
# Title: heise+ | Dynamische Strompreise nutzen: Ein Erfahrungsbericht mit Tibber
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Scarlett Johansson "schockiert und verärgert": OpenAI nimmt KI-Stimme offline
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
#
# Publication: 9to5Mac
# Title: Apple likely to produce quarter of iPhones in India by 2028, not half by 2027 as predicted
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Title: Vietnam urges Apple supplier Foxconn to cut power use by 30% amid energy concerns
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
# Title: Here’s how a tvOS restriction keeps game developers away from Apple TV
# Sentiment (SVM): Positive
# Sentiment (Together): Negative

# %%
import os
import requests
import pandas as pd
import sqlite3
import pickle

# Define the setup function
def setup():
    # Load your trained SVM model
    with open("svm_classifier.pkl", "rb") as f:
        svm_classifier = pickle.load(f)

    # Load the TF-IDF vectorizer
    with open("tfidf_vectorizer.pkl", "rb") as f:
        vectorizer = pickle.load(f)

    # Connect to SQLite database
    conn = sqlite3.connect("news_database.db")
    cursor = conn.cursor()

    return svm_classifier, vectorizer, cursor

# Call the setup function to get SVM classifier, TF-IDF vectorizer, and cursor
svm_classifier, vectorizer, cursor = setup()

# Function to predict sentiment for a given title using the SVM model
def predict_sentiment_svm(title):
    # Vectorize the title
    title_vectorized = vectorizer.transform([title])

    # Make prediction using SVM classifier
    prediction = svm_classifier.predict(title_vectorized)

    # Return the predicted sentiment (capitalized)
    return prediction[0].capitalize()

# Function to predict sentiment, political leaning, and bias for a given title using the Together model
def predict_sentiment_together(title):
    # Define the prompt
    prompt = f"""\
Label the sentence as either 'Positive', 'Negative', or 'Neutral', and indicate if the sentence is biased and what the political leaning is (Liberal, Conservative, Neutral):

Sentence: I can say that there isn't anything I would change.
Label: Positive, Not Biased, Neutral

Sentence: I'm not sure about this.
Label: Neutral, Not Biased, Neutral

Sentence: I think the background image could have been better.
Label: Negative, Not Biased, Neutral

Sentence: I really like it.
Label: Positive, Not Biased, Neutral

Sentence: The new policy will only benefit the wealthy.
Label: Negative, Biased, Liberal

Sentence: The government is taking necessary steps to help everyone.
Label: Positive, Biased, Conservative

Sentence: {title}
Label:"""

    # Make request to Together API
    endpoint = 'https://api.together.xyz/inference'
    TOGETHER_API_KEY = os.getenv('TOGETHER_API_KEY')

    res = requests.post(endpoint, json={
        "model": 'meta-llama/Llama-3-70b-chat-hf',
        "prompt": prompt,
        "top_p": 1,
        "top_k": 40,
        "temperature": 0.8,
        "max_tokens": 50,  # Increased to handle longer responses
        "repetition_penalty": 1,
    }, headers={
        "Authorization": f"Bearer {TOGETHER_API_KEY}",
        "User-Agent": "<YOUR_APP_NAME>"
    })

    # Extract sentiment, bias, and political leaning from response
    response_text = res.json()['output']['choices'][0]['text'].strip().split(", ")
    sentiment = response_text[0].capitalize()
    bias = response_text[1].capitalize()
    political_leaning = response_text[2].capitalize()

    return sentiment, bias, political_leaning

# Function to fetch the 10 newest articles for each publication and predict sentiment using both models
def predict_sentiment_for_newest_articles():
    # Dictionary to store sentiment predictions for each publication
    publication_sentiments = {}

    # Fetch unique publication names from the database
    cursor.execute("SELECT DISTINCT name FROM news_items")
    publications = cursor.fetchall()

    # Iterate over each publication
    for publication in publications:
        publication_name = publication[0]

        # Fetch the 10 newest articles for the current publication
        cursor.execute("SELECT title FROM news_items WHERE name=? ORDER BY published_at DESC LIMIT 10", (publication_name,))
        articles = cursor.fetchall()

        # List to store sentiment predictions for the current publication using both models
        publication_sentiments[publication_name] = []

        # Iterate over each article and predict sentiment using both models
        for article in articles:
            title = article[0]
            sentiment_svm = predict_sentiment_svm(title)
            sentiment_together, bias, political_leaning = predict_sentiment_together(title)
            publication_sentiments[publication_name].append((title, sentiment_svm, sentiment_together, bias, political_leaning))

    return publication_sentiments

# Predict sentiment for the 10 newest articles for each publication using both models
publication_sentiments = predict_sentiment_for_newest_articles()

# Print sentiment predictions for each publication
for publication, articles in publication_sentiments.items():
    print("Publication:", publication)
    for title, sentiment_svm, sentiment_together, bias, political_leaning in articles:
        print("Title:", title)
        print("Sentiment (SVM):", sentiment_svm)
        print("Sentiment (Together):", sentiment_together)
        print("Bias (Together):", bias)
        print("Political Leaning (Together):", political_leaning)
    print()
# Out:
# Publication: Associated Press
# Title: Tensions grips UCLA campus after police order protestors to disperse or face arrest - The Associated Press
# Sentiment (SVM): Negative
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: i will never vote for that candidate again.
# label: negative
# Title: Colombia's president says country will break diplomatic relations with Israel over war in Gaza - The Associated Press
# Sentiment (SVM): Negative
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the politician's statement was a lie.
# label: negative
# Title: Ex-Nickelodeon producer Schneider sues 'Quiet on Set' makers for defamation and sex abuse implications - The Associated Press
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral (note: this sentence is a news headline
# Title: Blinken presses Hamas to seal cease-fire with Israel, says 'the time is now' for a deal - The Associated Press
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: trump supporters are outraged after the election results.
# label: negative
# Title: Arizona Senate OKs bill to repeal the state's 1864 near-total abortion ban - The Associated Press
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the new policy is a disaster and will lead to economic ruin.
# label: negative
# Title: United Methodists repeal longstanding ban on LGBTQ clergy - The Associated Press
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the president's approval rating is at an all-time high.
# label: positive
# Title: Election 2024: Trump returns to campaign facing jail warning - The Associated Press
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Biased
# Political Leaning (Together): Conservative
#
# sentence: climate change is a hoax.
# label: negative
# Title: Mammograms should start at 40 to address rising breast cancer rates at younger ages, panel says - The Associated Press
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutralassistant
#
# here are the labeled sentences:
#
# sentence: i can say that there isn't anything i would change.
# label: positive
#
# Publication: CNN
# Title: Noem suggests Biden’s dog Commander should suffer a similar fate to Cricket, the dog she shot
# Sentiment (SVM): Negative
# Sentiment (Together): Negative
# Bias (Together): Biased
# Political Leaning (Together): Conservative
#
# sentence: the bill is an important step forward for women's rights.
# label: positive
# Title: Fifth body recovered from Baltimore bridge collapse site - CNN
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the new healthcare law is a disaster.
# label: negative
# Title: Task force updates guidance for breast cancer screenings for women 40 and older - CNN
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the new healthcare bill is a disaster for american families.
# label: negative
# Title: Police on campus at Columbia and UCLA as protests disrupt colleges nationwide: Live updates - CNN
# Sentiment (SVM): Negative
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the obama administration's economic policies have been a complete disaster.
# label: negative
#
# Publication: BBC News
# Title: Scarlett Johansson's AI row has echoes of Silicon Valley's bad old days
# Sentiment (SVM): Negative
# Sentiment (Together): Negative
# Bias (Together): Biased
# Political Leaning (Together): Liberal
#
# sentence: the politician's speech was inspiring and uplifting.
# label: positive
# Title: PSNI could be fined £750k over data breach
# Sentiment (SVM): Negative
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the government's new bill is a total disaster.
# label: negative
# Title: Bus crash leaves at least five children injured
# Sentiment (SVM): Negative
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: i'm a conservative and i love this policy.
# label: positive
# Title: How does the UK compare with other economies?
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: that is a very good policy.
# label: positive
# Title: Voters ‘distraught’ by direction of Conservatives, say Greens
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
# Bias (Together): Biased
# Political Leaning (Together): Liberal
#
# sentence: the economy is booming under conservative leadership.
# label: positive
# Title: Austrian man discovers mammoth bones in wine cellar
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the climate change crisis is real and we must act now.
# label: neutral
# Title: 'Missed opportunities' to prevent paedophile's murder
# Sentiment (SVM): Negative
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the new tax plan will help the economy.
# label: positive
# Title: Watch: Rishi Sunak's election announcement in full
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the prime minister is corrupt.
# label: negative
# Title: Sunak announces UK general election for 4 July
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the president's response to the crisis was lacking.
# label: negative
# Title: Tatler Kate portrait prompts strong reaction online
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: we can do better than this.
# label: negative
#
# Publication: CNBC
# Title: Moderna loses less than expected as Covid vaccine sales beat estimates, cost cuts take hold - CNBC
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: "the trump administration's policies have been a disaster for our country."
# label: negative
# Title: Stock futures rise after Fed decides to hold rates steady: Live updates - CNBC
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the liberal media is spreading fake news.
# label: negative
# Title: Long-predicted consumer pullback finally hits restaurants like Starbucks, KFC and McDonald's - CNBC
# Sentiment (SVM): Positive
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: it sounds like something a conservative would say.
# label: neutral
#
# Publication: Fox News
# Title: Harvey Weinstein faces new trial after rape conviction overturned, returns to prison - Fox News
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Biased
# Political Leaning (Together): Conservative
#
# sentence: the recent tax cuts will benefit the economy in the long run.
# label: positive
# Title: Volunteer searchers claim to have found secret crematorium in Mexico City - Fox News
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Biased
# Political Leaning (Together): Conservative
#
# sentence: the tax cuts will benefit the entire country.
# label: positive
# Title: Melissa McCarthy reacts to Barbra Streisand's awkward question about Ozempic - Fox News
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Biased
# Political Leaning (Together): Conservative
#
# sentence: the new healthcare bill is a huge step forward.
# label: positive
#
# Publication: Federalreserve.gov
# Title: Federal Reserve issues FOMC statement - Federal Reserve
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the politician is corrupt and wants to help big business.
# label: negative
#
# Publication: ABC News
# Title: Climber found dead after falling off highest peak in North America
# Sentiment (SVM): Negative
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: a study has found that the new policy has resulted in a 30% increase in homelessness.
# label: negative
# Title: Minors again found working at Alabama poultry plant where 16-year-old died, DOL says
# Sentiment (SVM): Negative
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the new law is a step in the right direction.
# label: positive
# Title: 35-year-old man survives grizzly bear attack after encountering 2 at national park
# Sentiment (SVM): Negative
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the new tax plan will help stimulate economic growth.
# label: positive
# Title: Hearing to determine if Missouri man who has been in prison for 33 years was wrongfully convicted
# Sentiment (SVM): Negative
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the new tax law will only benefit the rich.
# label: negative
# Title: American mistakenly accused of involvement in DRC coup attempt
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: these politicians are so corrupt.
# label: negative
# Title: Trump posts social media clip seemingly suggesting a win will bring 'unified Reich'
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
# Bias (Together): Biased
# Political Leaning (Together): Conservative
#
# sentence: aoc's green new deal is a game-changer.
# label: positive
# Title: Austin says 'expectation' is Ukraine won't use US weapons outside its territory
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the new tax reform will hurt the middle class.
# label: negative
# Title: WATCH: Bear finds nothing to eat in Florida garage fridge
# Sentiment (SVM): Negative
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: i have never been a fan of the design.
# label: negative
# Title: Prosecutor in Hunter Biden case plans to call ex-wife, brother's widow as witnesses
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: people are saying that the president's new plan is a disaster.
# label: negative
# Title: Moose kills Alaska man attempting to take photos of her newborn calves
# Sentiment (SVM): Negative
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: we need to raise taxes on the wealthy to fund social programs.
# label: neutral
#
# Publication: The Wall Street Journal
# Title: Tesla Is Pulling Back From EV Charging, and People Are Freaking Out - The Wall Street Journal
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: obama's health care plan is a joke.
# label: negative
#
# Publication: Politico
# Title: Has the DeSantis comeback already begun? - POLITICO - POLITICO
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Biased
# Political Leaning (Together): Conservative
#
# sentence: if you're a democrat
# Title: Officials warn of risks to 'certain groups' of people amid bird flu outbreak in cows - POLITICO
# Sentiment (SVM): Negative
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the liberal elites are trying to ruin our country.
# label: negative
# Title: RFK Jr. is all over conservative media. Trump's camp is concerned. - POLITICO
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Biased
# Political Leaning (Together): Conservative
#
# sentence: the administration is hiding information from the public.
# label: negative
#
# Publication: CBS Sports
# Title: NFL Power Rankings: Bengals, Jets rise with Joe Burrow, Aaron Rodgers back; stagnant Cowboys drop from top 10 - CBS Sports
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutralassistant
#
# here are the labeled sentences:
#
# sentence: i can say that there isn't anything i would change.
# label: positive
#
# Publication: New York Post
# Title: Ryan Garcia tested positive for PED before his win over Devin Haney - New York Post
# Sentiment (SVM): Positive
# Sentiment (Together): Neutral
# Bias (Together): Biased
# Political Leaning (Together): Conservative
#
# note: when labelling the sentence as biased
# Title: Prince William shares health update on Kate Middleton after her cancer diagnosis - New York Post
# Sentiment (SVM): Negative
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the government should be doing more for the people.
# label: negative
# Title: Tyrese Maxey wrecked Knicks' celebrity row: Tracy Morgan middle finger, 'seething' Ben Stiller and a Jon Stewart meme - New York Post
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the media is clearly biased against the current administration.
# label: negative
#
# Publication: Ars Technica
# Title: Netflix releases first look at new Witcher after Henry Cavill left for Warhammer 40K
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: this is a total disaster.
# label: negative
# Title: Here’s what’s really going on inside an LLM’s neural network
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: no one wants to hear it
# Title: A week with the Chevy Blazer EV shows things to love—but also painful flaws
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: it's a step in the right direction.
# label: positive
# Title: The first crew launch of Boeing’s Starliner capsule is on hold indefinitely
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the company's decision to increase prices is unfair.
# label: negative
# Title: Anti-pasteurization crowd reaffirms love of raw milk despite bird flu outbreak
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
# Bias (Together): Biased
# Political Leaning (Together): Conservative
#
# sentence: environmental protections are just a way to limit our freedom.
# label: negative
# Title: Disarmingly lifelike: ChatGPT-4o will laugh at your jokes and your dumb hat
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Bias (Together): Biased
# Political Leaning (Together): Liberal
#
# sentence: the new tax laws will create jobs.
# label: positive
# Title: Krysten Ritter has lost her memories in trailer for Orphan Black: Echoes
# Sentiment (SVM): Negative
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: you should totally vote for joe biden.
# label: positive
# Title: ChatGPT-4o allows real-time audio-video conversations with an “emotional” AI chatbot
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the proposal is flawed and should be rejected.
# label: negative
# Title: Elon Musk’s X dodges Australian order to remove church stabbing video
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the biden administration is a total disaster.
# label: negative
# Title: Beethoven likely didn’t die from lead poisoning, new DNA analysis reveals
# Sentiment (SVM): Negative
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: this new smartphone is one of the best on the market.
# label: positive
#
# Publication: The Verge
# Title: OpenAI’s News Corp deal licenses content from WSJ, New York Post, and more
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: it's ridiculous that we have to pay so much for healthcare.
# label: negative
# Title: Political ads could require AI-generated content disclosures soon
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: trump's policies have been a complete disaster.
# label: negative
# Title: Lawmakers debate ending Section 230 in order to save it
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: lawmakers debate ending section 230 to reign in the power of tech corporations
# label: negative
# Title: Big Tech thinks it can plant trees better than everyone else
# Sentiment (SVM): Positive
# Sentiment (Together): Negative
# Bias (Together): Biased
# Political Leaning (Together): Conservative
#
# sentence: the environmental regulations are too strict.
# label: negative
# Title: Meta’s Ray-Ban glasses will post Instagram stories for you
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# note that this is a subjective task
# Title: Super Mario Maker 64 exists, thanks to a new ROM hack
# Sentiment (SVM): Positive
# Sentiment (Together): Positive
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the company needs to improve its customer service.
# label: negative
# Title: Reddit’s deal with OpenAI will plug its posts into ‘ChatGPT and new products’
# Sentiment (SVM): Positive
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the current state of the economy is a disaster.
# label: negative
# Title: The Mac vs. PC war is back on
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the government's response was woefully inadequate.
# label: negative
# Title: X-Men ‘97 understood the power of perfect timing
# Sentiment (SVM): Positive
# Sentiment (Together): Positive
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: people are upset about the recent cuts to social programs.
# label: neutral
# Title: Nicolas Cage is back as Spider-Man in live-action Amazon series
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# please provide the labels for the following sentences:
#
# sentence: this new law is going to help so many people in need.
# label: ?
#
# sentence: people are getting tired of the constant changes.
# label: ?
#
# sentence
#
# Publication: National Institutes of Health
# Title: Endurance exercise affects all tissues of the body, even those not normally associated with movement - National Institutes of Health (NIH) (.gov)
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: as a conservative
#
# Publication: Futurism
# Title: China Releases CGI Video of Moon Base and It Contains Something Very Strange - Futurism
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the new healthcare bill will benefit all citizens
#
# Publication: PBS
# Title: What reclassifying marijuana means for Americans - PBS NewsHour
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutralassistant
#
# here are the labeled sentences:
#
# sentence: i can say that there isn't anything i would change.
# label: positive
#
# Publication: Axios
# Title: J&J baby powder settlement: Johnson & Johnson agrees to new $6.5B deal - Axios
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: president biden has signed an executive order to end the use of private prisons.
# label: positive
#
# Publication: Lanl.gov
# Title: New findings point to an Earth-like environment on ancient Mars - Discover LANL
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the new tax cut plan is a disaster.
# label: negative
#
# Publication: Road to VR
# Title: ‘Batman: Arkham Shadow’ Announced Exclusively for Quest 3 From Meta-owned Studio Behind ‘Iron Man VR’ - Road to VR
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: we must stand up against this oppressive administration.
# label: negative
#
# Publication: Yahoo Entertainment
# Title: Snap brings its AR lenses to Chrome through an extension
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# the labeling criteria is as follows:
#
# - positive: the sentence expresses a positive sentiment
# Title: There’s a new Vision show coming to Disney+ with Paul Bettany
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: i'm so sick of this show. it's so overrated.
# label: negative
# Title: Starliner’s first crew mission gets pushed back yet again, this time with no new launch date
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the company has been working hard to improve its services.
# label: positive
# Title: Sure, why not: China built a chatbot based on Xi Jinping
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Biased
# Political Leaning (Together): Conservative
#
# remember that the labels are subjective and may vary based on individual perspectives. the goal is to identify the sentiment and potential bias
# Title: Anker power banks are up to half off ahead of Memorial Day weekend
# Sentiment (SVM): Positive
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the new law is a great step forward.
# label: positive
# Title: Marvel's What If...? for Apple Vision Pro gets a trailer and release date
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the liberal media is spreading false information about the election.
# label: negative
# Title: Emory University awarded two students $10,000 for their AI study tool, then suspended them
# Sentiment (SVM): Negative
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the policy changes are going to make life worse for most people.
# label: negative
# Title: Nintendo snaps up a studio known for its Switch ports
# Sentiment (SVM): Positive
# Sentiment (Together): Positive
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the new law is a step in the right direction.
# label: positive
# Title: Japanese town overrun with tourists puts up view-blocking barrier near Mount Fuji
# Sentiment (SVM): Negative
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the proposed legislation is a step in the right direction for our country.
# label: positive
# Title: Ukraine firefighters tackle flames in Kharkiv after Russia carries out another strike on city
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
# Bias (Together): Not biased
# Political Leaning (Together): Neutralassistant
#
# here are the labeled sentences:
#
# sentence: i can say that there isn't anything i would change.
# label: positive
#
# Publication: cleveland.com
# Title: LeBron James addresses NBA future after Los Angeles Lakers playoff exit - cleveland.com
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the liberal media is at it again.
# label: negative
#
# Publication: The Washington Post
# Title: May night sky begins with Eta Aquariid meteor shower - The Washington Post
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the president is doing a great job.
# label: positive
#
# Publication: TechRadar
# Title: The Galaxy Watch Ultra is spotted again as Samsung hints at 'premium' smartwatches - TechRadar
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the samsung galaxy watch is available for preorders through amazon and through samsung's website.
# label: neutral
#
# Publication: NDTV News
# Title: After Maldives, Another Island Nation Elects Pro-China PM - Off Australia - NDTV
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the latest data shows that the economy is growing rapidly.
# label: positive
#
# Publication: USA Today
# Title: Body camera footage captures first responders' reactions in wake of Baltimore bridge collapse
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the liberal agenda is not doing anything for our economy.
# label: negative
# Title: Body camera footage captures first responders' reactions in wake of Baltimore bridge collapse
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the bill will provide economic opportunities for all americans.
# label: positive
# Title: Police officers, guns, and community collide: How the Charlotte house shooting happened - USA TODAY
# Sentiment (SVM): Negative
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: many are worried about the potential consequences of the new bill.
# label: negative
#
# Publication: NBC News
# Title: Arizona abortion ban fight jolts packed GOP House primary - NBC News
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Biased
# Political Leaning (Together): Conservative
#
# sentence: this new regulation is a huge step forward for the environment.
# label: positive
#
# Publication: Space.com
# Title: Here's what to expect during Boeing Starliner's 1st astronaut test flight on May 6 - Space.com
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the company's new policy is ridiculous.
# label: negative
# Title: Watch SpaceX's Crew-8 astronauts move their Dragon at the ISS May 2 to make way for Boeing's Starliner - Space.com
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the liberal media is pushing their own agenda.
# label: negative
#
# Publication: CBS News
# Title: Antisemitism Awareness Act passes House vote. Here's what the bill does. - CBS New York
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the administration has shown total disregard for the people's well-being.
# label: negative
#
# Publication: NPR
# Title: Nikki Haley says she'll vote for Trump
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Biased
# Political Leaning (Together): Conservative
#
# sentence: the new tax reform is a great step forward.
# label: positive
# Title: After years in decline, U.S. drowning deaths are rising again
# Sentiment (SVM): Negative
# Sentiment (Together): Negative
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: gun violence is out of control in america.
# label: negative
# Title: Lack of staffing led to 'deeply concerning' conditions at federal prison in Oregon
# Sentiment (SVM): Negative
# Sentiment (Together): Negative
# Bias (Together): Biased
# Political Leaning (Together): Liberal
#
# sentence: i'm happy to see that the government is finally doing something about the border crisis.
# label: positive
# Title: The MacArthur Foundation wants bold solutions to big problems — the prize is $100M
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the new development is a disaster waiting to happen.
# label: negative
# Title: Ireland, Norway, Spain to recognize a Palestinian state; stay safe during turbulence
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# the dataset includes 12,000+ sentences
# Title: Buy-now, pay-later returns and disputes are about to get federal oversight
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the new law could have been implemented better.
# label: negative
# Title: Stephen King's new story took him 45 years to write. He tells NPR why
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the people who say they are not afraid of you are the ones you should fear.
# label: neutral
# Title: A big survey asked Americans about their finances. Here are some trouble spots
# Sentiment (SVM): Negative
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: this shows that the company has a deep understanding of the market.
# label: positive
# Title: 6 key facts about abortion laws and the 2024 election
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the latest proposal by the government is a total disaster.
# label: negative
# Title: Norway, Ireland and Spain say they will recognize a Palestinian state
# Sentiment (SVM): Negative
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: i think that the new policy is not good for the country.
# label: negative
#
# Publication: Daily Beast
# Title: Trump Piles on Hush-Money Judge After Jail Time Warning - The Daily Beast
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
# Bias (Together): Biased
# Political Leaning (Together): Liberal
#
# sentence: the mainstream media is spreading fake news again.
# label: negative
#
# Publication: Sportsnet.ca
# Title: Oilers’ special teams, top players too much for outmatched Kings in Round 1 - Sportsnet.ca
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: this is the worst article i've read all year.
# label: negative
#
# Publication: ESPN
# Title: Mavs' Luka Doncic dominates Game 5 despite illness, knee injury - ESPN
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutralassistant
#
# here are the labeled sentences:
#
# sentence: i can say that there isn't anything i would change.
# label: positive
#
# Publication: ScienceAlert
# Title: Curiosity Detects 'Habitable' Earth-Like Past on Mars, But How Did Oxygen Get There? - ScienceAlert
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the new policy is a total disaster.
# label: negative
#
# Publication: NBCSports.com
# Title: Ezekiel Elliott on return to Cowboys: I'm here to chase a dream - NBC Sports
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutralassistant
#
# here are the labeled sentences:
#
# sentence: i can say that there isn't anything i would change.
# label: positive
#
# Publication: WKOW
# Title: Mount Horeb police shoot, kill student with gun outside middle school - WKOW
# Sentiment (SVM): Negative
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: i'm glad that this product is made in the usa.
# label: positive
#
# Publication: Fortune
# Title: Bird flu in Texas has spread to some workers - Fortune
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: joe biden is a great president.
# label: positive
#
# Publication: Lifehacker.com
# Title: Google Phone's New Audio Emojis for Android Include a Fart Button - Lifehacker
# Sentiment (SVM): Positive
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: in the future
#
# Publication: GameSpot
# Title: Stay At The X-Mansion With AirBnb, Danger Room Included - GameSpot
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: there's no one-size-fits-all solution to this problem.
# label: neutral
#
# Publication: Dark Horizons
# Title: "Batman: Arkham Shadow" VR Game Trailer - Dark Horizons
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: i'm just saying that the game is very well made.
# label: positive
#
# Publication: Inverse
# Title: Chrome's New Built-in AI Is The Biggest Update To the Browser In Over 15 Years - Inverse
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Bias (Together): Biased
# Political Leaning (Together): Neutral
#
# sentence: i think there are more issues with the new browser than just the ai.
# label: negative
#
# Publication: NASA
# Title: What's Up: May 2024 Skywatching Tips from NASA - Science@NASA
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: we must take immediate action to protect our planet from climate change.
# label: positive
#
# Publication: Cdc.gov
# Title: Preventable Premature Deaths from the Five Leading Causes of Death in Nonmetropolitan and Metropolitan Counties, United States, 2010–2022 | MMWR - CDC
# Sentiment (SVM): Negative
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: this is complete and utter nonsense.
# label: negative
#
# Publication: Wired
# Title: How to Clear Your Browser's Cache, and Why You Should
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: we should focus on renewable energy.
# label: positive
# Title: What Scarlett Johansson v. OpenAI Could Look Like in Court
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the latest climate report is a stark reminder of the urgent need for action.
# label: negative
# Title: Local Coworking Spaces Thrive Where WeWork Dared Not Go
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Biased
# Political Leaning (Together): Liberal
#
# sentence: the economy is doing great under the current administration.
# label: positive
# Title: We Stood on Both Sides of the New York–Dublin Portal and It Was Glorious
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the new bill is a step in the right direction.
# label: positive
# Title: /e/OS Review: This Operating System Is Better Than Android. You Should Try It
# Sentiment (SVM): Positive
# Sentiment (Together): Positive
# Bias (Together): Biased
# Political Leaning (Together): Liberal
#
# sentence: the new tax reform is a complete disaster.
# label: negative
# Title: A Far-Right Indian News Site Posts Racist Conspiracies. US Tech Companies Keep Platforming It
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
# Bias (Together): Biased
# Political Leaning (Together): Liberal
#
# sentence: the democratic party's only goal is to take away our guns.
# label: negative
# Title: Neuralink’s First User Is ‘Constantly Multitasking’ With His Brain Implant
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: elon musk is a visionary leader.
# label: positive
# Title: The World Is Ignoring the Other Deadly Kind of Carbon
# Sentiment (SVM): Negative
# Sentiment (Together): Negative
# Bias (Together): Biased
# Political Leaning (Together): Liberal
#
# sentence: the president's comments were out of line.
# label: negative
# Title: The Complex Social Lives of Viruses
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral (note: this sentence is a title and does not express an opinion)
#
# remember
# Title: Razer Fujin Pro Gaming Chair Review: Giving My Back an Extra Life
# Sentiment (SVM): Positive
# Sentiment (Together): Positive
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the food at this restaurant is always amazing.
# label: positive
#
# Publication: Gizmodo.com
# Title: 10 Standout Sci-Fi, Horror, and Fantasy Series on Max
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: there is no evidence that this policy will benefit anyone.
# label: negative
# Title: James Wan Wants to Bring Back The Munsters for Universal's Monsterverse
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the president's tweet about the border wall is a total disaster.
# label: negative
# Title: Human Infected With Bird Flu in Michigan, Only the Second Case of Current Outbreak
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: what the government is doing to the economy is unbelievable.
# label: negative
# Title: Predator and Black Panther Will Collide in a New Marvel Mini-Series
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: donald trump is an amazing leader.
# label: positive
# Title: Electric Vehicles Are More Likely to Hit Pedestrians Than Gas Cars Are, Study Finds
# Sentiment (SVM): Negative
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the data from the study was manipulated to fit the desired outcome.
# label: negative
# Title: Groundbreaking Measurement Reveals a Black Hole Spinning at a Quarter the Speed of Light
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: this new policy will be a disaster.
# label: negative
# Title: Marvel's Upcoming What If? VR Game Gets a Revealing First Trailer
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the latest report from the washington post shows that...
# label: neutral
# Title: Alexa Will Get an Upgrade But It'll Cost You, Report Says
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the new tax law is a disaster.
# label: negative
# Title: OpenAI Unveils GPT-4 Omni’s Voice Capabilities and They’re Literally Unbelievable
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: i think the new policy will benefit everyone.
# label: positive
# Title: Canadian Wildfire Smoke Blows Into U.S., Setting Stage for Another Miserable Summer
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Biased
# Political Leaning (Together): Liberal
#
# sentence: the administration is doing great job.
# label: positive
#
# Publication: InsideClimate News
# Title: Storing energy with compressed air is about to have its moment of truth
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutralassistant
#
# here are the labeled sentences:
#
# sentence: i can say that there isn't anything i would change.
# label: positive
#
# Publication: Seths.blog
# Title: “I don’t learn that way”
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: i love this!
# label: positive
# Title: Pet quirks
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: i love this restaurant!
# label: positive
# Title: The strategy sessions
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
#  sentence: this company has done a great job.
# label: positive
# Title: The strategy sessions
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: i think that the company made an excellent choice.
# label: positive
# Title: The defensive arrogance of TL;DR
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
# Bias (Together): Biased
# Political Leaning (Together): Conservative
#
# sentence: the president is doing a great job.
# label: positive
# Title: The half-life of magic
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: this is the best thing that has ever happened in the history of humanity!
# label: positive
# Title: She’s here!
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: i don't think that's true.
# label: negative
# Title: Don’t rush
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the economy is growing faster than ever.
# label: positive
# Title: Beyond CRM
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: a new study shows that climate change is real.
# label: neutral
# Title: The other choices
# Sentiment (SVM): Negative
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
#
# 1. this policy is terrible and we need to get rid of it.
# label: negative
#
# Publication: Android Central
# Title: Our favorite phone of 2024 (so far) just scored a HUGE discount during Amazon's Memorial Day sale
# Sentiment (SVM): Positive
# Sentiment (Together): Positive
# Bias (Together): Biased
# Political Leaning (Together): Conservative
#
# sentence: the new tax law will only hurt the poor.
# label: negative
# Title: A cleaner Google Messages text field rolls out to more users
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: biden's administration has been a disaster.
# label: negative
# Title: Galaxy Z Flip 6, Fold 6 might drop Exynos for the Snapdragon 8 Gen 3 'exclusively'
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: he's a fantastic teacher
# Title: The Google Gemini app still isn't available for some phones. Why not?
# Sentiment (SVM): Negative
# Sentiment (Together): Negative
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: i am very upset about the new law.
# label: negative
# Title: Wearable AI brand Humane looking to sell, sources say
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: ai-powered chatbots are the future of customer support.
# label: positive
# Title: Ray-Ban Meta AI and more looks to be coming to Quest soon
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the company's decision was a huge mistake.
# label: negative
# Title: OpenAI trying to steal Scarlett Johansson's voice to make AI feel 'comfortable' is the reason why it's so worrying
# Sentiment (SVM): Negative
# Sentiment (Together): Negative
# Bias (Together): Biased
# Political Leaning (Together): Liberal
#
# sentence: the mayor's new plan will help people of all income levels.
# label: positive
# Title: First 12 things to do with the Pixel 8a
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the tax cuts will help the economy.
# label: positive
# Title: Google Play Points introduces new features to enhance user rewards
# Sentiment (SVM): Positive
# Sentiment (Together): Positive
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the new healthcare bill is a step in the right direction.
# label: positive
# Title: Honor's upcoming smartphones will include Google's generative AI features
# Sentiment (SVM): Positive
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: this is the worst customer service i have ever encountered.
# label: negative
#
# Publication: MacRumors
# Title: Apple's 2024 M4 Mac Mini: What We Know
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the best part about it is that it has a great battery life.
# label: positive
# Title: What the Golf on Apple Vision Pro Gains New Levels
# Sentiment (SVM): Positive
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the tax cuts are a great achievement for our country.
# label: positive
# Title: Best M4 iPad Pro Cases Currently Available
# Sentiment (SVM): Positive
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: this company has a history of prioritizing profits over people.
# label: negative
# Title: Apple Music Reveals Top 10 Albums of All Time
# Sentiment (SVM): Positive
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: apple music is the best music streaming service.
# label: positive
# Title: Apple Adds Support for Live Activities to Shazam
# Sentiment (SVM): Positive
# Sentiment (Together): Positive
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: i am against this policy.
# label: negative
# Title: iOS 17.5 Features: What's New in iOS 17.5
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the iphone 14 is much better than the iphone 13.
# label: positive
# Title: Setapp's EU Alternative iPhone App Marketplace Launching on May 14
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: this is an outrage!
# label: negative
# Title: iPad Marketing VP: iPad and Mac are Complementary Devices, Not Competing Devices
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: a recent survey found that most people don't trust the government.
# label: neutral
# Title: HDR Bug Impacts OLED iPad Pro, Apple Working on Software Fix
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the president's approval ratings are plummeting.
# label: negative
# Title: M2 iPad Air Reviews: A Larger Display at a More Affordable Price
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# ...
# label: positive
#
# Publication: WPIX 11 New York
# Title: Boeing is on the verge of launching astronauts into space in new capsule
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: this restaurant has the worst service.
# label: negative
#
# Publication: Makezine.com
# Title: Mobile Mojo Mastery using Wireless Desktop CNC
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral (this sentence doesn't express an opinion or emotion)
#
# in this dataset
# Title: Making Makers: Building Makerspaces in K–12 Parochial Schools
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: i'm not sure if what is said is true.
# label: neutral
#
# Publication: The Daily Meal
# Title: The Ultimate Ranking Of Canned Roast Beef, According To Customer Reviews
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: this is the best company i have ever worked with.
# label: positive
# Title: The Ultimate Ranking Of Canned Roast Beef, According To Customer Reviews
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: i love the product.
# label: positive
#
# Publication: Fall River Herald News
# Title: Lafayette Park pool renovations to close lane on Eastern Avenue: What you need to know
# Sentiment (SVM): Neutral
# Sentiment (Together): Neural
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the park needs to be renovated
# Title: Lafayette Park pool renovations to close lane on Eastern Avenue: What you need to know
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutralassistant
#
# here are the labeled sentences:
#
# 1. sentence: i can say that there isn't anything i would change.
# label: positive
#
# Publication: Time
# Title: Horizon Is More a Tribute to Great Westerns Than a Great One Itself
# Sentiment (SVM): Positive
# Sentiment (Together): Negative
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# note: the sentences are taken from real-world reviews
# Title: Trump Media and Technology Group Posts Over $300M Net Loss in First Public Quarter
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: this new policy will benefit everyone regardless of their income.
# label: positive
# Title: Moose Kills Alaska Man Attempting to Take Photos of Her Calves
# Sentiment (SVM): Negative
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutralassistant
#
# here are the labeled sentences:
#
# sentence: i can say that there isn't anything i would change.
# label: positive
# Title: Boredom Makes Us Human
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the media is controlled by the government.
# label: negative
# Title: Boredom Makes Us Human
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutralassistant
#
# here are the labeled sentences:
#
# sentence: i can say that there isn't anything i would change.
# label: positive
#
# Publication: Xataka.com
# Title: Max ya está aquí: todas las diferencias con HBO Max y las novedades que trae la nueva plataforma de Warner
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral (note: this sentence is in spanish and appears to be a factual summary
# Title: Scarlett Johansson, "enfadada e incrédula" por el parecido de la voz de ChatGPT con la suya. No le sirve la respuesta de OpenAI
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
# Bias (Together): Biased
# Political Leaning (Together): Liberal
#
# sentence: the politician's comments were out of touch with reality.
# label: negative
# Title: Microsoft persigue el sueño de tener su propio MacBook Air con los PCs Copilot+. Es el intento más convincente que recordamos
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: i believe the tax cuts are the way to go.
# label: positive
# Title: Los mejores descuentos en dispositivos Xiaomi los tienes en Powerplanet: ahorro para gamers, melómanos o internautas
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: this is an absolute disaster.
# label: negative
# Title: Tras el boom del alquiler vacacional, llega el del alquiler de piscinas: se expande y ya deja sobresueldos de 10.000 euros
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: ¡es un asco! ¡eso no es democracia!
# label: negative
# Title: Copilot+ llega a un arsenal de nuevos portátiles: Acer, ASUS, Dell, HP, Lenovo y Samsung se apuntan a lo último de Qualcomm y Microsoft
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the company is the best in the industry.
# label: positive
# Title: La Redmi Pad Pro es la nueva tablet calidad-precio de Xiaomi: sus características son un espectáculo
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# note that the 'neutral' label here does not necessarily mean that the sentence expresses no opinion
#
# Publication: Cool Hunting
# Title: iF Design’s 2024 Trend Report and Conference
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: i do not agree with the new policy.
# label: negative
#
# Publication: Le Monde
# Title: Trois recettes légères et pas chères du petit-déjeuner au dîner
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral (note: this sentence is in french
# Title: La campagne de Donald Trump attaquée pour une vidéo mentionnant un « Reich unifié »
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
# Bias (Together): Biased
# Political Leaning (Together): Liberalassistant
#
# here are the labels for each sentence:
#
# sentence: i can say that there isn't anything i would change.
# label: positive
# Title: En direct, guerre en Ukraine : « Nous gardons le contrôle partout », assure Volodymyr Zelensky
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral (note: this sentence is in french and is a statement from ukraine's president during the ukraine-russia conflict. the label is based on the tone and content of the sentence
# Title: Sur Parcoursup, des candidats en réorientation désavantagés : « Un parcours non linéaire et des hésitations sont considérés comme suspects »
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
# Bias (Together): Biased
# Political Leaning (Together): Liberal (translation: "on parcoursup
#
# Publication: IGN
# Title: Kingdom Hearts Series Coming to Steam Next Month
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the new law will only benefit the wealthy.
# label: negative
#
# Publication: Digital Trends
# Title: SpaceX photos show important Starship pre-flight rehearsal
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# now
#
# Publication: Pcloadletter.dev
# Title: The ChatGPT wrapper product boom is an uncanny valley hellscape
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
# Bias (Together): Biased
# Political Leaning (Together): Liberal
#
# sentence: the company's values align with my own.
# label: positive
#
# Publication: Bumblemeow.com
# Title: Comparing desktop development tools, Qt, Electron and macOS Native
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: i do not agree with the changes.
# label: negative
#
# Publication: Proton.me
# Title: How (and why) to de-Google your life and protect your privacy
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Biased
# Political Leaning (Together): Liberal
#
# sentence: the new health insurance plan is a disaster.
# label: negative
#
# Publication: Andymatuschak.org
# Title: How Might We Learn?
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the new policy is a disaster.
# label: negative
#
# Publication: Whatheco.de
# Title: CamelCase vs. Snake_case Scientific Studies
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Biased
# Political Leaning (Together): Neutralassistant
#
# here are the labeled sentences:
#
# sentence: i can say that there isn't anything i would change.
# label: positive
#
# Publication: Substack.com
# Title: The OpenAI board was right – No (by a voice actres named Scarlet) means No
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Bias (Together): Biased
# Political Leaning (Together): Liberal
#
# sentence: the president is doing a fantastic job.
# label: positive
#
# Publication: Stripe.com
# Title: Stripe increasing "instant payout" fees by 50%
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the company's commitment to diversity and inclusion is impressive.
# label: positive
#
# Publication: Tomblomfield.com
# Title: Taking Risk – Startups in UK vs. US
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the best part is that it’s not run by the government.
# label: positive
#
# Publication: Arxiv.org
# Title: Chameleon: Meta's New Multi-Modal LLM
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: that's just a stupid idea.
# label: negative
#
# Publication: N8s.site
# Title: Async Rust Isn't Bad: You Are
# Sentiment (SVM): Negative
# Sentiment (Together): Positive
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: it's the best decision that we have ever made.
# label: positive
#
# Publication: Modos.tech
# Title: Modos Paper Monitor Pre-Launch on Crowd Supply
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: it's a great step forward for the community.
# label: positive
#
# Publication: Gigazine.net
# Title: Metaがインドの選挙期間中に偽情報や暴力を扇動するAIが生成した画像を含むFacebook広告を承認していたことが判明
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
# Bias (Together): Biased
# Political Leaning (Together): Liberalassistant
#
# here are the labeled sentences:
#
# sentence: i can say that there isn't anything i would change.
# label: positive
# Title: Microsoftが「第11世代Surface Pro」と「第7世代Surface Laptop」を発表、Snapdragon X Elite／Plus搭載でAI処理に最適
# Sentiment (SVM): Positive
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: there's no need to panic about the coronavirus.
# label: positive
# Title: ガラパゴスに行かずとも大量のイグアナに会えるタークス・カイコスのリトル・ウォーター・ケイに行ってみた【インターリンク ドメイン島巡り 第45回「.tc」】
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# note: the last sentence is in japanese and is about visiting turks and caicos islands.
#
# please format your answers as follows:
#
#  sentence: [insert sentence]
# label: [insert label]
#
# the labels should be formatted
#
# Publication: Blogger.com
# Title: "Mortgage Rates Close Enough to Unchanged Over The Weekend"
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the tax cut is a disaster for the economy.
# label: negative
#
# Publication: heise online
# Title: heise+ | Marktübersicht: KI-Server mit GPUs im Überblick
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: i think we should have a more progressive tax system.
# label: neutral
# Title: Video: Ist die perfekte DIY-Schleifmaschine möglich?
# Sentiment (SVM): Negative
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral (note: this is a non-english sentence
# Title: Photovoltaik: China baut größtes Offshore-Solarkraftwerk der Welt
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the government is taking necessary steps to help everyone
# Title: Vor Jahren gelöschte iPhone-Fotos kehren zurück: iOS 17.5.1 soll Bug beseitigen
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral (note: this sentence is in german
# Title: heise-Angebot: iX-Workshop IEC 62443: IT-Sicherheit in der Produktentwicklung
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
#  sentence: there's nothing i'd change.
# label: positive
# Title: Kryptogeldbetrug über eine Milliarde US-Dollar: Genesis zahlt zwei Milliarden
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral (note: this is a news headline in german
# Title: heise+ | Growboxen ausprobiert: Digital unterstützte Anzuchtboxen für den Cannabis-Anbau
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutralassistant
#
# here are the labeled sentences:
#
# sentence: i can say that there isn't anything i would change.
# label: positive
# Title: Wieder Brand durch E-Bike-Akku: Feuerwehr warnt vor dem Laden in der Wohnung
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral (note: this sentence is in german and translates to "rebranding through e-bike battery: fire department warns against charging in the apartment")
#
# sentence: the liberal elites are out of touch with the working class
# Title: heise+ | Dynamische Strompreise nutzen: Ein Erfahrungsbericht mit Tibber
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral (note: this sentence appears to be a headline or title and does not express a clear opinion)
#
# sentence: i think the president is doing a great job.
# label: positive
# Title: Scarlett Johansson "schockiert und verärgert": OpenAI nimmt KI-Stimme offline
# Sentiment (SVM): Neutral
# Sentiment (Together): Negative
# Bias (Together): Not biased
# Political Leaning (Together): Neutralassistant
#
# here are the labeled sentences:
#
# sentence: i can say that there isn't anything i would change.
# label: positive
#
# Publication: 9to5Mac
# Title: Apple likely to produce quarter of iPhones in India by 2028, not half by 2027 as predicted
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the politician made a statement to calm down the protesters.
# label: neutral
# Title: Vietnam urges Apple supplier Foxconn to cut power use by 30% amid energy concerns
# Sentiment (SVM): Neutral
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: the new tax reform will help stimulate economic growth.
# label: positive
# Title: Here’s how a tvOS restriction keeps game developers away from Apple TV
# Sentiment (SVM): Positive
# Sentiment (Together): Neutral
# Bias (Together): Not biased
# Political Leaning (Together): Neutral
#
# sentence: i hope they will make some changes.
# label: neutral

# %%
import os
import requests
import sqlite3
import pickle

# Define the setup function to load SVM model and TF-IDF vectorizer
def setup():
    # Load the SVM model
    with open("svm_classifier.pkl", "rb") as f:
        svm_classifier = pickle.load(f)

    # Load the TF-IDF vectorizer
    with open("tfidf_vectorizer.pkl", "rb") as f:
        vectorizer = pickle.load(f)

    # Connect to SQLite database
    conn = sqlite3.connect("news_database.db")
    cursor = conn.cursor()

    return svm_classifier, vectorizer, cursor

# Call the setup function to get SVM classifier, TF-IDF vectorizer, and cursor
svm_classifier, vectorizer, cursor = setup()

# Function to predict sentiment for a given title using the SVM model
def predict_sentiment_svm(title):
    # Vectorize the title
    title_vectorized = vectorizer.transform([title])

    # Make prediction using SVM classifier
    prediction = svm_classifier.predict(title_vectorized)

    # Return the predicted sentiment (capitalized)
    return prediction[0].capitalize()

# Function to predict sentiment, political leaning, and bias for a given title using the Together model
def predict_sentiment_together(title):
    # Define the prompt for the Together API
    prompt = f"""\
Label the news headline as either 'Positive', 'Negative', or 'Neutral', and indicate if the sentence is biased and what the political leaning is (Liberal, Conservative, Neutral):

Headline: {title}
Label:"""

    # Make request to Together API
    endpoint = 'https://api.together.xyz/inference'
    TOGETHER_API_KEY = os.getenv('TOGETHER_API_KEY')

    res = requests.post(endpoint, json={
        "model": 'meta-llama/Llama-3-70b-chat-hf',
        "prompt": prompt,
        "top_p": 1,
        "top_k": 40,
        "temperature": 0.8,
        "max_tokens": 50,  # Increased to handle longer responses
        "repetition_penalty": 1,
    }, headers={
        "Authorization": f"Bearer {TOGETHER_API_KEY}",
        "User-Agent": "<YOUR_APP_NAME>"
    })

    # Extract sentiment, bias, and political leaning from response
    response_choices = res.json()['output']['choices']
    for choice in response_choices:
        text = choice['text'].strip()
        if text.startswith("Positive"):
            sentiment = "Positive"
        elif text.startswith("Negative"):
            sentiment = "Negative"
        elif text.startswith("Neutral"):
            sentiment = "Neutral"
        else:
            sentiment = "Unknown"

        if "Biased" in text:
            bias = "Biased"
        else:
            bias = "Not Biased"

        if "Liberal" in text:
            political_leaning = "Liberal"
        elif "Conservative" in text:
            political_leaning = "Conservative"
        elif "Neutral" in text:
            political_leaning = "Neutral"
        else:
            political_leaning = "Unknown"

        if sentiment != "Unknown" and bias != "Unknown" and political_leaning != "Unknown":
            break  # Exit loop if all values are found

    return sentiment, bias, political_leaning

# Function to fetch the 10 newest articles and predict sentiment using both models
def predict_sentiment_for_newest_articles(max_articles=3):
    # List to store sentiment predictions
    all_articles_sentiments = []

    # Fetch the newest articles from the database
    cursor.execute("SELECT title FROM news_items ORDER BY published_at DESC LIMIT ?", (max_articles,))
    articles = cursor.fetchall()

    # Iterate over each article and predict sentiment using both models
    for article in articles:
        title = article[0]
        sentiment_svm = predict_sentiment_svm(title)
        sentiment_together, bias, political_leaning = predict_sentiment_together(title)
        all_articles_sentiments.append((title, sentiment_svm, sentiment_together, bias, political_leaning))

    return all_articles_sentiments

# Predict sentiment for the newest articles using both models
articles_sentiments = predict_sentiment_for_newest_articles()

# Print sentiment predictions
for title, sentiment_svm, sentiment_together, bias, political_leaning in articles_sentiments:
    print("Title:", title)
    print("Sentiment (SVM):", sentiment_svm)
    print("Sentiment (Together):", sentiment_together)
    print("Bias (Together):", bias)
    print("Political Leaning (Together):", political_leaning)
    print()
# Out:
# Title: Scarlett Johansson's AI row has echoes of Silicon Valley's bad old days
# Sentiment (SVM): Negative
# Sentiment (Together): Neutral
# Bias (Together): Not Biased
# Political Leaning (Together): Neutral
#
# Title: PSNI could be fined £750k over data breach
# Sentiment (SVM): Negative
# Sentiment (Together): Neutral
# Bias (Together): Not Biased
# Political Leaning (Together): Neutral
#
# Title: Nikki Haley says she'll vote for Trump
# Sentiment (SVM): Neutral
# Sentiment (Together): Positive
# Bias (Together): Not Biased
# Political Leaning (Together): Conservative
